# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv('IRIS.csv')
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
train, test=train_test_split(df,test_size=0.25)
test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 94            5.6          2.7           4.2          1.3  Iris-versicolor
# 88            5.6          3.0           4.1          1.3  Iris-versicolor
# 98            5.1          2.5           3.0          1.1  Iris-versicolor
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 78            6.0          2.9           4.5          1.5  Iris-versicolor
# 45            4.8          3.0           1.4          0.3      Iris-setosa
# 12            4.8          3.0           1.4          0.1      Iris-setosa
# 116           6.5          3.0           5.5          1.8   Iris-virginica
# 84            5.4          3.0           4.5          1.5  Iris-versicolor
# 95            5.7          3.0           4.2          1.2  Iris-versicolor
# 85            6.0          3.4           4.5          1.6  Iris-versicolor
# ...

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
train_x=train[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
train_x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 51            6.4          3.2           4.5          1.5
# 53            5.5          2.3           4.0          1.3
# 5             5.4          3.9           1.7          0.4
# 129           7.2          3.0           5.8          1.6
# 46            5.1          3.8           1.6          0.2
# ..            ...          ...           ...          ...
# 20            5.4          3.4           1.7          0.2
# 6             4.6          3.4           1.4          0.3
# 93            5.0          2.3           3.3          1.0
# 16            5.4          3.9           1.3          0.4
# 35            5.0          3.2           1.2          0.2
#
# [112 rows x 4 columns]

# %%
train_l=train[['species']]

# %%
train_l
# Out:
#              species
# 51   Iris-versicolor
# 53   Iris-versicolor
# 5        Iris-setosa
# 129   Iris-virginica
# 46       Iris-setosa
# ..               ...
# 20       Iris-setosa
# 6        Iris-setosa
# 93   Iris-versicolor
# 16       Iris-setosa
# 35       Iris-setosa
#
# [112 rows x 1 columns]

# %%
test_x=train[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
test_l=train[['species']]

# %% [markdown]
# ### Model Selection

# %%
model = svm.SVC()

# %%
model.fit(train_x,train_l)
pre = model.predict(test_x)
# Out:
# C:\Users\MR OSMAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
metrics.accuracy_score(pre,test_l)
# Out:
# 0.9821428571428571

# %%
# with the help of decision tree
model1 = DecisionTreeClassifier()
model1.fit(train_x,train_l)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(test_x)
metrics.accuracy_score(pred,test_l)
# Out:
# 0.9821428571428571
