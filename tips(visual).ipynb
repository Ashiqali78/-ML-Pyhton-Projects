# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('tips')

# %%
new_data = df.head(240)

# %%
type(new_data)
# Out:
# pandas.core.frame.DataFrame

# %%
new_data.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
new_data.shape
# Out:
# (240, 7)

# %%
new_data.drop('sex',axis=1,inplace=True)
# Out:
# C:\Users\MR OSMAN\AppData\Local\Temp\ipykernel_14004\3011089396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.drop('sex',axis=1,inplace=True)

# %%
new_data.drop('day',axis=1,inplace=True)
# Out:
# C:\Users\MR OSMAN\AppData\Local\Temp\ipykernel_14004\4045870390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.drop('day',axis=1,inplace=True)

# %%
new_data.drop('smoker',axis=1,inplace=True)
# Out:
# C:\Users\MR OSMAN\AppData\Local\Temp\ipykernel_14004\3895884496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.drop('smoker',axis=1,inplace=True)

# %%
new_data.drop('time',axis=1,inplace=True)
# Out:
# C:\Users\MR OSMAN\AppData\Local\Temp\ipykernel_14004\3072617416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.drop('time',axis=1,inplace=True)

# %%
new_data
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 235       10.07  1.25     2
# 236       12.60  1.00     2
# 237       32.83  1.17     2
# 238       35.83  4.67     3
# 239       29.03  5.92     3
#
# [240 rows x 3 columns]

# %%
new_data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.682219  0.603250
# tip           0.682219  1.000000  0.486767
# size          0.603250  0.486767  1.000000

# %% [markdown]
# *The range is b/w -1 to 1 1 indicates strong relation*

# %%
sns.heatmap(new_data.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=new_data,kind='hex')

# %% [markdown]
# *It will indicte that the concentration is more around 10 to 20 and the tip amount is around 2 to 3$*
# *So if the bill is around 10 to 20$ the tip is max*

# %%
sns.jointplot(x='tip',y='total_bill',data=new_data,kind='reg')

# %%
sns.pairplot(new_data)

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.pairplot(df,hue='sex')

# %% [markdown]
# *So Man are more then women*

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.pairplot(df,hue='smoker')

# %% [markdown]
# *So non-smoker are more then smoker*

# %% [markdown]
# ### Catagorical graphs

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Count plot
sns.countplot(x='sex',data=df,hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df,hue='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day',data=df,hue='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
# bar ployt
sns.barplot(data=df,x='sex',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# sns.barplot(x='smoker',y='sex',data=df,hue='sex')

# %%
sns.boxplot(data=df,x='smoker',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(data=df,x='total_bill',y='day',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# vilonplot
sns.violinplot(data=df,x='total_bill',y='day',palette='rainbow')
# Out:
# C:\Users\MR OSMAN\AppData\Local\Temp\ipykernel_1260\2795897341.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df,x='total_bill',y='day',palette='rainbow')
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## Practice

# %%
Data=sns.load_dataset('iris')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 Data=sns.load_dataset('iris')
#
# TypeError: 'str' object is not callable

# %%
# Out:
# 'iris'
